# %%
from sz.tushare.pro_bar import bar_data
from sz.charts.stock_chart import ohlc_of_bar_df, volume_of_bar_df

# %%
df = bar_data(ts_code = '002001.SZ', start_date = '20160101', adj='qfq')

# %%
df.head(3)
# Out:
#      ts_code  trade_date   open   high    low  close  pre_close  change  \
# 0  002001.SZ    20190902  23.77  23.77  23.15  23.61      23.59    0.02
# 1  002001.SZ    20190830  23.75  24.20  23.31  23.59      23.72   -0.13
# 2  002001.SZ    20190829  22.32  23.99  22.23  23.72      22.31    1.41
#
#    pct_chg        vol      amount
# 0   0.0848  221779.58  520382.389
# 1  -0.5481  231370.13  547116.237
# 2   6.3200  422448.05  982675.523

# %%
# for index, row in df.iterrows():
#     print('index: %s, trade_date: %s\n' % (index, row['trade_date']))

# %%
print(volume_of_bar_df(df))
# Out:
# [
#     [
#         1451869200000,
#         98539.96
#     ],
#     [
#         1451955600000,
#         118185.27
#     ],
#     [
#         1452042000000,
#         79746.05
#     ],
#     [
#         1452128400000,
#         21939.47
#     ],
#     [
#         1452214800000,
#         109460.27
#     ],
#     [
#         1452474000000,
#         139866.83
#     ],
#     [
#         1452560400000,
#         123990.1
#     ],
#     [
#         1452646800000,
#         135886.01
#     ],
#     [
#         1452733200000,
#         103286.75
#     ],
#     [
#         1452819600000,
#         102195.55
#     ],
#     [
#         1453078800000,
#         98820.86
#     ],
#     [
#         1453165200000,
#         266513.5
#     ],
#     [
#         1453251600000,
#         447764.23
#     ],
#     [
#         1453338000000,
#         782200.28
#     ],
#     [
#         1453424400000,
#         551369.39
#     ],
#     [
#         1453683600000,
#         373142.15
#     ],
#     [
# ...

# %%
# %%javascript
# alert('hello');
